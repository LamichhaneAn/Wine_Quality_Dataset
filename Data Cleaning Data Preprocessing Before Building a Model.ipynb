# %%
import pandas as pd

df = pd.read_csv("winequality.csv")
df
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
df.head(10)
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
# 5  white            8.1              0.28         0.40             6.9
# 6  white            6.2              0.32         0.16             7.0
# 7  white            7.0              0.27         0.36            20.7
# 8  white            6.3              0.30         0.34             1.6
# 9  white            8.1              0.22         0.43             1.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
df.columns
# Out:
# Index(['type', 'fixed acidity', 'volatile acidity', 'citric acid',
#        'residual sugar', 'chlorides', 'free sulfur dioxide',
#        'total sulfur dioxide', 'density', 'pH', 'sulphates', 'alcohol',
#        'quality'],
#       dtype='object')

# %%
df.size
# Out:
# 84461

# %%
df.shape
# Out:
# (6497, 13)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6497, step=1)

# %%
df.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
#finding missing values in percentage

df.isnull().sum() / df.shape[0] * 100
# Out:
# type                    0.000000
# fixed acidity           0.153917
# volatile acidity        0.123134
# citric acid             0.046175
# residual sugar          0.030783
# chlorides               0.030783
# free sulfur dioxide     0.000000
# total sulfur dioxide    0.000000
# density                 0.000000
# pH                      0.138525
# sulphates               0.061567
# alcohol                 0.000000
# quality                 0.000000
# dtype: float64

# %%
#finding duplicated

df.duplicated().sum()
# Out:
# 1168

# %%
#identifying the garbage values using for loop

for i in df.select_dtypes(include="object").columns:
    #print("Column:", i)
    print(df[i].value_counts())
    print("***" * 10)
# Out:
# type
# white    4898
# red      1599
# Name: count, dtype: int64
# ******************************

# %%
# - Exploratory Data Analysis(EDA)

df.describe(include='all')
# Out:
#          type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497    6487.000000       6489.000000  6494.000000     6495.000000
# unique      2            NaN               NaN          NaN             NaN
# top     white            NaN               NaN          NaN             NaN
# freq     4898            NaN               NaN          NaN             NaN
# mean      NaN       7.216579          0.339691     0.318722        5.444326
# std       NaN       1.296750          0.164649     0.145265        4.758125
# min       NaN       3.800000          0.080000     0.000000        0.600000
# 25%       NaN       6.400000          0.230000     0.250000        1.800000
# 50%       NaN       7.000000          0.290000     0.310000        3.000000
# 75%       NaN       7.700000          0.400000     0.390000        8.100000
# max       NaN      15.900000          1.580000     1.660000       65.800000
#
# ...

# %%
# - Exploratory Data Analysis(EDA)

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %%
df.describe(include = "object")
# Out:
#          type
# count    6497
# unique      2
# top     white
# freq     4898

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'zscore'],
#       dtype='object')

# %%
#histogram to understand the distribution
import warnings
import seaborn as sns
import matplotlib.pyplot as plt

# Ignore warnings
warnings.filterwarnings("ignore")

# Loop through each numeric column to create histograms
for i in df.select_dtypes(include="number").columns:
    sns.histplot(data=df, x=i, kde=True)  # Added kde=True to include Kernel Density Estimate if desired
    plt.title(f'Histogram of {i}')  # Optional: Add a title for clarity
    plt.show()

# %%
#Boxplot to identify outliers:

import warnings
import seaborn as sns
import matplotlib.pyplot as plt

# Ignore warnings
warnings.filterwarnings("ignore")

# Loop through each numeric column to create boxplots
for i in df.select_dtypes(include="number").columns:
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')  # Optional: Add a title for clarity
    plt.show()

# %%
#scatter plot to understand the relationship
# residual sugar is a target variable here so i will remove this from columns

import seaborn as sns
import matplotlib.pyplot as plt

# List of features excluding 'residual sugar'
features = ['fixed acidity', 'volatile acidity', 'citric acid', 'chlorides',
            'free sulfur dioxide', 'total sulfur dioxide', 'density', 'pH',
            'sulphates', 'alcohol', 'quality', 'zscore']

# Loop through each feature to create scatter plots
for i in features:
    sns.scatterplot(data=df, x=i, y="residual sugar")
    plt.title(f'Scatter plot of residual sugar vs {i}')  # Optional: Add a title for clarity
    plt.show()

# %%
#correlation with heatmap to interpret the relation and multicolliniarity

# Calculate the correlation matrix for all numeric columns
correlation_matrix = df.select_dtypes(include="number").corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219872     0.323498
# volatile acidity           0.219872          1.000000    -0.377827
# citric acid                0.323498         -0.377827     1.000000
# residual sugar            -0.112194         -0.196275     0.142411
# chlorides                  0.298249          0.377141     0.039247
# free sulfur dioxide       -0.283164         -0.353016     0.133412
# total sulfur dioxide      -0.329421         -0.414857     0.195137
# density                    0.458943          0.271144     0.096294
# pH                        -0.251750          0.260459    -0.328371
# sulphates                  0.300198          0.225160     0.057651
# alcohol                   -0.095561         -0.038083    -0.010418
# quality                   -0.076931         -0.265901     0.085704
# zscore                    -0.112194         -0.196275     0.142411
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize the correlation matrix with a heatmap
plt.figure(figsize=(10, 8))  # Optional: Set the figure size for better visibility
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df["residual sugar"].mean()
# Out:
# 5.44357395721102

# %%
df["residual sugar"].std()
# Out:
# 4.75758548476171

# %%
#distplot to understand the distribution - Visualize the Data

import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")
sns.histplot(df["residual sugar"], kde=True) #kde=True: Adds a Kernel Density Estimate (KDE) line to the histogram, showing the smoothed distribution of data.
plt.show()

# %%
# Creating a boxplot to visualize outliers in the 'residual sugar' column


import seaborn as sns
import matplotlib.pyplot as plt

#to see outliners clearly

sns.boxplot(df["residual sugar"])
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Creating a boxplot to visualize outliers in the 'residual sugar' column

sns.boxplot(x=df['residual sugar'])
plt.show()

# %%
#Missing Value Treatments:

#choose the method of imputting missing value - Another Method
#like mean, median, mode or 

#new_df = df.copy()
#new_df = df.fillna(-999)
#new_df.isnull().sum()

# %%
for i in ["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides", "pH", "sulphates"]:
    df[i].fillna(df[i].median(), inplace = True)

df.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# -  Outliers Treatments:
# Z-score Method: - first find the limits:

upper_limit = df["residual sugar"].mean() + 3*df["residual sugar"].std()
lower_limit = df["residual sugar"].mean() - 3*df["residual sugar"].std()
print("upper_limit : ", upper_limit)
print("lower_limit : ", lower_limit)
# Out:
# upper_limit :  19.716330411496152
# lower_limit :  -8.82918249707411

# %%
#find the outliers:

outliers = df[(df["residual sugar"] > upper_limit) | (df["residual sugar"] < lower_limit)]
outliers
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 7     white            7.0             0.270         0.36           20.70
# 182   white            6.8             0.280         0.40           22.00
# 191   white            6.8             0.280         0.40           22.00
# 292   white            7.4             0.280         0.42           19.80
# 444   white            6.9             0.240         0.36           20.80
# 1454  white            8.3             0.210         0.49           19.80
# 1608  white            6.9             0.270         0.49           23.50
# 1653  white            7.9             0.330         0.28           31.60
# 1663  white            7.9             0.330         0.28           31.60
# 2489  white            6.1             0.280         0.24           19.95
# 2492  white            6.1             0.280         0.24           19.95
# ...

# %%
outliers.shape
# Out:
# (26, 13)

# %%
#triming - delete the outlier data: non_outliers means new_df

non_outliers = df[(df["residual sugar"] < upper_limit) & (df["residual sugar"] > lower_limit)]
non_outliers
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# 5     white            8.1             0.280         0.40             6.9
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#triming - delete the outlier data: non_outliers means new_df

non_outliers = df[(df["residual sugar"] < upper_limit) & (df["residual sugar"] > lower_limit)]

print("before removing outliers :", len(df))
print("after removing outliers (non_outliners):", len(non_outliers))
print("Total outliers are : ", len(df) - len(non_outliers))
# Out:
# before removing outliers : 6497
# after removing outliers (non_outliners): 6471
# Total outliers are :  26

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Creating a boxplot to visualize outliers in the 'residual sugar' column
sns.boxplot(x=non_outliers["residual sugar"])
plt.show()

# %%
#if you don't want to delete the whole row than we can do capping method
# -  capping - change the outlier values to upper (or) lower limit values:
#it is also filtering the outliers


non_outliers = df.copy()

# Cap values greater than upper_limit
non_outliers.loc[non_outliers["residual sugar"] > upper_limit, "residual sugar"] = upper_limit

# Cap values less than lower_limit
non_outliers.loc[non_outliers["residual sugar"] < lower_limit, "residual sugar"] = lower_limit

# %%
sns.boxplot(x=non_outliers["residual sugar"])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
#Here we have not deleted any of the data rather we have capped it . 
#We can check by printing the length of data



len(non_outliers)



#We can see that length of new dataframe is 6497 which is same as the old dataframe
# Out:
# 6497

# %%
df["zscore"] = (df["residual sugar"] - df["residual sugar"].mean()) / df["residual sugar"].std()
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality    zscore
# 0       0.45      8.8        6  3.206758
# ...

# %%
print("z-score of 1st row",(20.7 - 5.44)/4.75)
# Out:
# z-score of 1st row 3.212631578947368

# %%
df[df["zscore"]>3]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 7     white            7.0             0.270         0.36           20.70
# 182   white            6.8             0.280         0.40           22.00
# 191   white            6.8             0.280         0.40           22.00
# 292   white            7.4             0.280         0.42           19.80
# 444   white            6.9             0.240         0.36           20.80
# 1454  white            8.3             0.210         0.49           19.80
# 1608  white            6.9             0.270         0.49           23.50
# 1653  white            7.9             0.330         0.28           31.60
# 1663  white            7.9             0.330         0.28           31.60
# 2489  white            6.1             0.280         0.24           19.95
# 2492  white            6.1             0.280         0.24           19.95
# ...

# %%
df[df["zscore"]<-3]
# Out:
# Empty DataFrame
# Columns: [type, fixed acidity, volatile acidity, citric acid, residual sugar, chlorides, free sulfur dioxide, total sulfur dioxide, density, pH, sulphates, alcohol, quality, zscore]
# Index: []

# %%
df[(df.zscore < 3) | (df.zscore > 3)]

#outliers
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#Inter Quartile Range Method: IQR

q1 = df["residual sugar"].quantile(0.25)
q3 = df["residual sugar"].quantile(0.75)
iqr = q3-q1

print("q1 :", q1)
print("q3 :", q3)
print("iqr:", iqr)
# Out:
# q1 : 1.8
# q3 : 8.1
# iqr: 6.3

# %%
#Next let us calculate the upper and lower limit using the Interquartile Range (IQR) method

upper_limit = q3 + (1.5 * iqr)
lower_limit = q1 - (1.5 * iqr)

lower_limit , upper_limit
# Out:
# (-7.6499999999999995, 17.549999999999997)

# %%
sns.boxplot(x=df["residual sugar"])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
#Next we will find the outliers using upper and lower limit calculated earlie

#find the outliers:

outliners_iqr = df[(df["residual sugar"] > upper_limit) | (df["residual sugar"] < lower_limit)]
outliners_iqr
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 7     white            7.0             0.270         0.36           20.70
# 14    white            8.3             0.420         0.62           19.25
# 38    white            7.3             0.240         0.39           17.95
# 39    white            7.3             0.240         0.39           17.95
# ...     ...            ...               ...          ...             ...
# 4691  white            6.9             0.190         0.31           19.25
# 4694  white            6.9             0.190         0.31           19.25
# 4748  white            6.1             0.340         0.24           18.35
# 4749  white            6.2             0.350         0.25           18.40
# 4778  white            5.8             0.315         0.19           19.40
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#trimming or delete the outliners data

non_outliers_iqr = df[(df["residual sugar"] < upper_limit) & (df["residual sugar"] > lower_limit)]
non_outliers_iqr
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 4     white            7.2             0.230         0.32             8.5
# 5     white            8.1             0.280         0.40             6.9
# ...     ...            ...               ...          ...             ...
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6494    red            6.3             0.510         0.13             2.3
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
non_outliers_iqr = df[(df["residual sugar"] < upper_limit) & (df["residual sugar"] > lower_limit)]


print("before removing the outliners : ", len(df))
print("after removing the outliners :", len(non_outliers_iqr))
print("Total IQR_Outliners are :", len(df) - len(non_outliers_iqr))
# Out:
# before removing the outliners :  6497
# after removing the outliners : 6379
# Total IQR_Outliners are : 118

# %%
sns.boxplot(x=non_outliers_iqr["residual sugar"])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
# - capping - change the outliner value to upper (or) lower values

#if you don't want to delete the whole row than we can do capping method
# -  capping - change the outlier values to upper (or) lower limit values:
#it is also filtering the outliers


non_outliers_iqr = df.copy()

# Cap values greater than upper_limit
non_outliers_iqr.loc[non_outliers_iqr["residual sugar"] > upper_limit, "residual sugar"] = upper_limit

# Cap values less than lower_limit
non_outliers_iqr.loc[non_outliers_iqr["residual sugar"] < lower_limit, "residual sugar"] = lower_limit

# %%
sns.boxplot(x=non_outliers_iqr['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
#Percentile Method

upper_limit = df['residual sugar'].quantile(0.99)
lower_limit = df['residual sugar'].quantile(0.01)
print('upper limit:', upper_limit)
print('lower limit:', lower_limit)
# Out:
# upper limit: 18.2
# lower limit: 0.9

# %%
sns.boxplot(x=df['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
#Next we will find the outliers using upper and lower limit calculated earlier

# find the outliers

outliner_percentile = df.loc[(df['residual sugar'] > upper_limit) | (df['residual sugar'] < lower_limit)]
outliner_percentile
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 7     white            7.0             0.270         0.36           20.70
# 14    white            8.3             0.420         0.62           19.25
# 103   white            7.5             0.305         0.40           18.90
# 111   white            7.2             0.270         0.46           18.75
# ...     ...            ...               ...          ...             ...
# 4749  white            6.2             0.350         0.25           18.40
# 4778  white            5.8             0.315         0.19           19.40
# 4779  white            6.0             0.590         0.00            0.80
# 4877  white            5.9             0.540         0.00            0.80
# 4897  white            6.0             0.210         0.38            0.80
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
#Next let us perform trimming of the outliers

# trimming - delete the outlier data


non_outliner_percentile = df.loc[(df['residual sugar'] <= upper_limit) & (df['residual sugar'] >= lower_limit)]
print('before removing outliers:', len(df))
print('after removing outliers:',len(non_outliner_percentile))
print('outliers:', len(df)-len(non_outliner_percentile))
# Out:
# before removing outliers: 6497
# after removing outliers: 6400
# outliers: 97

# %%
sns.boxplot(x=non_outliner_percentile['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
#Next let us perform capping of the outliers

# capping - change the outlier values to upper (or) lower limit values

non_outliner_percentile = df.copy()
non_outliner_percentile.loc[(non_outliner_percentile['residual sugar']>upper_limit), 'residual sugar'] = upper_limit
non_outliner_percentile.loc[(non_outliner_percentile['residual sugar']<lower_limit), 'residual sugar'] = lower_limit

# %%
#Next let us plot the data after performing capping

sns.boxplot(x=non_outliner_percentile['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar'>

# %%
#Next let us plot the distplot for both old and new dataframe

sns.distplot(df['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar', ylabel='Density'>

# %%
sns.distplot(non_outliner_percentile['residual sugar'])
# Out:
# <Axes: xlabel='residual sugar', ylabel='Density'>

# %%
# Duplicates & Garbage Value Treatments:

#check for duplicate if we have any unique column in the data set, delete the columns by using drop dublicate

#clean the garbage value

#to drop the dublicate columns

df.drop_duplicates()
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36            20.7
# 1     white            6.3             0.300         0.34             1.6
# 2     white            8.1             0.280         0.40             6.9
# 3     white            7.2             0.230         0.32             8.5
# 6     white            6.2             0.320         0.16             7.0
# ...     ...            ...               ...          ...             ...
# 6491    red            6.8             0.620         0.08             1.9
# 6492    red            6.2             0.600         0.08             2.0
# 6493    red            5.9             0.550         0.10             2.2
# 6495    red            5.9             0.645         0.12             2.0
# 6496    red            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
# - Encoding of data

#before fitting the dataset in model we all need the columns in numerical

# DO label encoding and one hot encoding with pd.getdummies

#so we have the column "Type" in object data-form now we need to convert this column into numerical this is called encode

# %%
dummy= pd.get_dummies(data = df, columns = ["type"], drop_first=True)
dummy

#now my data is ready to fit in the model by using either regression, or scaler
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0             0.270         0.36            20.7      0.045
# 1               6.3             0.300         0.34             1.6      0.049
# 2               8.1             0.280         0.40             6.9      0.050
# 3               7.2             0.230         0.32             8.5      0.058
# 4               7.2             0.230         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 6492            6.2             0.600         0.08             2.0      0.090
# 6493            5.9             0.550         0.10             2.2      0.062
# 6494            6.3             0.510         0.13             2.3      0.076
# 6495            5.9             0.645         0.12             2.0      0.075
# 6496            6.0             0.310         0.47             3.6      0.067
#
# ...
